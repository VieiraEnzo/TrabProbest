# %% [markdown]
# # Leitura dos dados

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
smart = pd.read_csv('dataset_smart-tv.csv')
chromecast = pd.read_csv('dataset_chromecast.csv')

# %%
smart['upLog'] = smart.bytes_up.apply(lambda x: x if x == 0 else math.log(x,10))
smart['downLog'] = smart.bytes_down.apply(lambda x: x if x == 0 else math.log(x,10))

chromecast['upLog'] = chromecast.bytes_up.apply(lambda x: x if x == 0 else math.log(x,10))
chromecast['downLog'] = chromecast.bytes_down.apply(lambda x: x if x == 0 else math.log(x,10))

# %%
chromecast.head()
# Out:
#    device_id            date_hour     bytes_up    bytes_down     upLog  \
# 0   66161985  2021-09-06 00:01:00  2987.016393  49185.704918  3.475238
# 1   66161985  2021-09-06 00:02:00   685.935484    328.258065  2.836283
# 2   66161985  2021-09-06 00:03:00  4493.901639  37914.064516  3.652624
# 3   66161985  2021-09-06 00:04:00   776.133333    229.200000  2.889936
# 4   66161985  2021-09-06 00:05:00  3081.311475  51656.800000  3.488736
#
#     downLog
# 0  4.691839
# 1  2.516215
# 2  4.578800
# 3  2.360215
# 4  4.713127

# %%
DownloadColor = 'red'
UploadColor = 'skyblue'

# %% [markdown]
# # Estatísticas Gerais

# %% [markdown]
# ## Estudo dos datasets

# %%
smart.head()
#chromecast.head()
# Out:
#    device_id            date_hour       bytes_up    bytes_down     upLog  \
# 0   77209603  2021-11-22 15:23:00  132932.983607  2.818140e+06  5.123633
# 1   77209603  2021-11-22 15:24:00  115770.491803  2.264410e+06  5.063598
# 2   77209603  2021-11-22 15:25:00  114030.032787  2.309270e+06  5.057019
# 3   77209603  2021-11-22 15:26:00   97170.622951  2.006544e+06  4.987535
# 4   77209603  2021-11-22 15:27:00   39569.573770  8.061440e+05  4.597361
#
#     downLog
# 0  6.449962
# 1  6.354955
# 2  6.363475
# 3  6.302449
# 4  5.906413

# %% [markdown]
# ## Média, Variancia e Desvio padrão

# %%
#Para smart-tv

meanSmartUp = smart.bytes_up.mean()
varianceSmartUp = smart.bytes_up.var()
desvSmartUp = smart.bytes_up.std()

meanSmartDown = smart.bytes_down.mean()
varianceSmartDown = smart.bytes_down.var()
desvSmartDown = smart.bytes_down.std()

print("<Smart TV> ")
print("Média Up: ",meanSmartUp)
print("Média Down: ",meanSmartDown)
print("Var Up: ", varianceSmartUp)
print("Var Down: ",varianceSmartDown)
print("Desv Up: ", desvSmartUp)
print("Desv Down: ",desvSmartDown)

#Para chromecast

meanChromeUp = chromecast.bytes_up.mean()
varianceChromeUp = chromecast.bytes_up.var()
desvChromeUp = chromecast.bytes_up.std()

meanChromeDown = chromecast.bytes_down.mean()
varianceChromeDown = chromecast.bytes_down.var()
desvChromeDown = chromecast.bytes_down.std()

print("<Chromecast> ")
print("Média Up: ",meanChromeUp)
print("Média Down: ",meanChromeDown)
print("Var Up: ", varianceChromeUp)
print("Var Down: ",varianceChromeDown)
print("Desv Up: ", desvChromeUp)
print("Desv Down: ",desvChromeDown)
# Out:
# <Smart TV>
# Média Up:  27572.75148454971
# Média Down:  824978.0194616826
# Var Up:  130846152481.18608
# Var Down:  5425589937520.203
# Desv Up:  361726.62672408577
# Desv Down:  2329289.5778584946
# <Chromecast>
# Média Up:  10119.255358818338
# Média Down:  287724.9317994046
# Var Up:  1081823576.3012624
# Var Down:  1057638524087.4263
# Desv Up:  32891.08657830055
# Desv Down:  1028415.5405707492

# %% [markdown]
# ## Histograma

# %% [markdown]
# ### Smart

# %%
#calculando a bin
n = len(smart.upLog)
k = round(1 + math.log2(n))


# Criando o histograma
smart.upLog.hist(bins = k ,edgecolor='black',color = UploadColor)

# Adicionando títulos e rótulos
plt.title('Histograma upload')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

# Plotando o gráfico
plt.show()

################################################################################

#calculando a bin
n = len(smart.downLog)
k = round(1 + math.log2(n))

# Criando o histograma
smart.downLog.hist(bins = k ,edgecolor='black',color= DownloadColor)

# Adicionando títulos e rótulos
plt.title('Histograma download')
plt.xlabel('log(bps) download')
plt.ylabel('Frequência')

# Plotando o gráfico
plt.show()

###########################################

#calculando a bin
n = len(smart.upLog)
k = round(1 + math.log2(n))

# Criando o histograma
smart.upLog.hist(bins = k ,edgecolor='black',color= UploadColor)

#calculando a bin
n = len(smart.downLog)
k = round(1 + math.log2(n))

# Criando o histograma
smart.downLog.hist(bins = k ,edgecolor='black',color= DownloadColor)

# Adicionando títulos e rótulos
plt.title('Histograma download x upload')
plt.xlabel('log(bps)')
plt.ylabel('Frequência')

# Plotando o gráfico
plt.show()

# %% [markdown]
# ### Chrome

# %%
#calculando a bin
n = len(chromecast.upLog)
k = round(1 + math.log2(n))


# Criando o histograma
chromecast.upLog.hist(bins = k ,edgecolor='black',color= UploadColor)

# Adicionando títulos e rótulos
plt.title('Histograma upload')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

# Plotando o gráfico
plt.show()

################################################################################

#calculando a bin
n = len(chromecast.downLog)
k = round(1 + math.log2(n))

# Criando o histograma
chromecast.downLog.hist(bins = k ,edgecolor='black',color= DownloadColor)

# Adicionando títulos e rótulos
plt.title('Histograma download')
plt.xlabel('log(bps) download')
plt.ylabel('Frequência')

# Plotando o gráfico
plt.show()

###########################################

#calculando a bin
n = len(chromecast.upLog)
k = round(1 + math.log2(n))

# Criando o histograma
chromecast.upLog.hist(bins = k ,edgecolor='black',color= UploadColor)

#calculando a bin
n = len(smart.downLog)
k = round(1 + math.log2(n))

# Criando o histograma
chromecast.downLog.hist(bins = k ,edgecolor='black',color= DownloadColor)

# Adicionando títulos e rótulos
plt.title('Histograma download x upload')
plt.xlabel('log(bps)')
plt.ylabel('Frequência')

# Plotando o gráfico
plt.show()

# %% [markdown]
# ## Boxplot

# %% [markdown]
# ### Smart

# %%
plt.boxplot(smart.upLog)

plt.title('Boxplot upload')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

plt.show()

#######################################

plt.boxplot(smart.downLog)

plt.title('Boxplot Download')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

plt.show()

# %% [markdown]
# ### Chrome

# %%
plt.boxplot(chromecast.upLog)

plt.title('Boxplot upload')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

plt.show()

#######################################

plt.boxplot(chromecast.downLog)

plt.title('Boxplot Download')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

plt.show()

# %% [markdown]
# ### Ambos

# %%
fig, ax = plt.subplots()

bp = ax.boxplot([smart['upLog'], chromecast['upLog'], smart['downLog'], chromecast['downLog']], patch_artist=True)

colors = [UploadColor, UploadColor, DownloadColor, DownloadColor]
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

ax.set_xticklabels(['SmartUpLog', 'ChromeUpLog', 'SmartDownLog','ChromeDownLog'])

plt.show()

# %% [markdown]
# ## função de distribuição empírica

# %% [markdown]
# ### Smart

# %%
def FuncDistEmp(lista): 
    lista.sort()
    return [(i+1)/len(lista) for i in range(len(lista))]

x1 = smart['downLog'].to_list()
x1.sort()

plt.plot(x1, FuncDistEmp(smart['downLog'].to_list()), marker='.', linestyle='none', color='red')

plt.title('ECDF download')
plt.xlabel('Valores dos dados')
plt.ylabel('Proporção cumulativa')

plt.show()

###########################################################################

x1 = smart['upLog'].to_list()
x1.sort()

plt.plot(x1, FuncDistEmp(smart['upLog'].to_list()), marker='.', linestyle='none', color='skyblue')

plt.title('ECDF upload')
plt.xlabel('Valores dos dados')
plt.ylabel('Proporção cumulativa')

plt.show()

# %% [markdown]
# ### Chromecast

# %%
x1 = chromecast['downLog'].to_list()
x1.sort()

plt.plot(x1, FuncDistEmp(chromecast['downLog'].to_list()), marker='.', linestyle='none', color='red')

plt.title('ECDF download')
plt.xlabel('Valores dos dados')
plt.ylabel('Proporção cumulativa')

plt.show()

###########################################################################

x1 = chromecast['upLog'].to_list()
x1.sort()

plt.plot(x1, FuncDistEmp(chromecast['upLog'].to_list()), marker='.', linestyle='none', color='skyblue')

plt.title('ECDF upload')
plt.xlabel('Valores dos dados')
plt.ylabel('Proporção cumulativa')

plt.show()

# %% [markdown]
# # Estatística por horario

# %% [markdown]
# Re-organizando os dados

# %%
smart['date_hour'] = pd.to_datetime(smart['date_hour'])
smart = smart.set_index('date_hour')

chromecast['date_hour'] = pd.to_datetime(chromecast['date_hour'])
chromecast = chromecast.set_index('date_hour')

# %%
groupedSmart = smart.groupby(smart.index.hour)

meanSmart = groupedSmart.mean()
varianceSmart = groupedSmart.var()
std_devSmart = groupedSmart.std()

############################################

groupedChrome = chromecast.groupby(chromecast.index.hour)

meanChrome = groupedChrome.mean()
varianceChrome = groupedChrome.var()
std_devChrome = groupedChrome.std()

# %%
meanSmart.head()
# Out:
#               device_id      bytes_up     bytes_down     upLog   downLog
# date_hour
# 0          5.541630e+07  25151.774595  783597.902833  1.892633  2.103765
# 1          5.525449e+07  17589.627985  596789.183395  1.465755  1.600724
# 2          5.539055e+07  12296.198604  438659.794772  1.151734  1.227714
# 3          5.555769e+07   7096.611366  262706.523172  0.891317  0.896688
# 4          5.565124e+07   4658.851083  169020.840265  0.766631  0.734832

# %% [markdown]
# ## Média

# %%
plt.bar(range(24), meanSmart.upLog, color = UploadColor)
plt.title('Mean Upload Smart-TV')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

##############################

plt.bar(range(24), meanSmart.downLog, color=DownloadColor)
plt.title('Mean Download Smart-TV')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

# %%
plt.bar(range(24), meanChrome.upLog, color = UploadColor)
plt.title('Mean Upload Chromecast')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

##############################

plt.bar(range(24), meanChrome.downLog, color = DownloadColor)
plt.title('Mean Download Chromecast')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

# %% [markdown]
# ## Variancia

# %%
plt.bar(range(24), varianceSmart.upLog, color = UploadColor)
plt.title('Mean Upload Smart-TV')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

##############################

plt.bar(range(24), varianceSmart.downLog, color=DownloadColor)
plt.title('Mean Download Smart-TV')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

# %%
plt.bar(range(24), varianceChrome.upLog, color = UploadColor)
plt.title('Mean Upload Chromecast')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

##############################

plt.bar(range(24), varianceChrome.downLog, color = DownloadColor)
plt.title('Mean Download Chromecast')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

# %% [markdown]
# ## Desvio Padrão

# %%
plt.bar(range(24), std_devSmart.upLog, color = UploadColor)
plt.title('Mean Upload Smart-TV')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

##############################

plt.bar(range(24), std_devSmart.downLog, color=DownloadColor)
plt.title('Mean Download Smart-TV')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

# %%
plt.bar(range(24), std_devChrome.upLog, color = UploadColor)
plt.title('Mean Upload Chromecast')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

##############################

plt.bar(range(24), std_devChrome.downLog, color = DownloadColor)
plt.title('Mean Download Chromecast')
plt.xlabel('Hour')
plt.ylabel('Mean')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
fig, ax = plt.subplots(figsize=(16, 6))

# For each hour in the grouped data
for i, (hour, group) in enumerate(groupedSmart):
    ax.boxplot(group['upLog'], positions=[i])

ax.set_xticks(range(len(groupedSmart)))
ax.set_title('Upload Smart-TV')
plt.show()

#############################################################

fig, ax = plt.subplots(figsize=(16, 6))

# For each hour in the grouped data
for i, (hour, group) in enumerate(groupedSmart):
    ax.boxplot(group['downLog'], positions=[i])

ax.set_xticks(range(len(groupedSmart)))
ax.set_title('Download Smart-TV')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 6))

# For each hour in the grouped data
for i, (hour, group) in enumerate(groupedChrome):
    ax.boxplot(group['upLog'], positions=[i])

ax.set_xticks(range(len(groupedChrome)))
ax.set_title('Upload Chromecast')
plt.show()

#############################################################

fig, ax = plt.subplots(figsize=(16, 6))

# For each hour in the grouped data
for i, (hour, group) in enumerate(groupedChrome):
    ax.boxplot(group['downLog'], positions=[i])

ax.set_xticks(range(len(groupedChrome)))
ax.set_title('Download Chromecas')
plt.show()

# %% [markdown]
# # Caracterizando os horarios com maior valor de trafego

# %%
meanSmart.idxmax()
meanChrome.idxmax()
# Out:
# device_id     10
# bytes_up      23
# bytes_down    23
# upLog         22
# downLog       23
# dtype: int32

# %%
print("(1) Horario com a maior media da taxa de upload em uma hora, Smart-TV: 20 horas")
print("(2) Horario com a maior media da taxa de download em uma hora, Smart-TV: 20 horas")
print("(3) Horario com a maior media da taxa de upload em uma hora, Chromecast: 22 horas")
print("(4) Horario com a maior media da taxa de download em uma hora, Chromecast: 23 horas")
# Out:
# (1) Horario com a maior media da taxa de upload em uma hora, Smart-TV: 20 horas
# (2) Horario com a maior media da taxa de download em uma hora, Smart-TV: 20 horas
# (3) Horario com a maior media da taxa de upload em uma hora, Chromecast: 22 horas
# (4) Horario com a maior media da taxa de download em uma hora, Chromecast: 23 horas

# %%
smart_up_max = groupedSmart.get_group(20)
smart_down_max = groupedSmart.get_group(22)
chrome_up_max = groupedChrome.get_group(22)
chrome_down_max = groupedChrome.get_group(23)
len(smart_up_max), len(smart_down_max), len(chrome_up_max), len(chrome_down_max)
# Out:
# (212608, 204892, 76738, 71848)

# %% [markdown]
# ## HISTOGRAMAS

# %%
#calculando a bin
n = len(smart_up_max.upLog)
k = round(1 + math.log2(n))

smart_up_max.upLog.hist(bins = k ,edgecolor='black',color= UploadColor)

plt.title('Histograma upload')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

plt.show()

#######################################################

#calculando a bin
n = len(smart_down_max.downLog)
k = round(1 + math.log2(n))

smart_down_max.downLog.hist(bins = k ,edgecolor='black',color= DownloadColor)

plt.title('Histograma Download')
plt.xlabel('log(bps) download')
plt.ylabel('Frequência')

plt.show()

# %%
#calculando a bin
n = len(chrome_up_max.upLog)
k = round(1 + math.log2(n))

chrome_up_max.upLog.hist(bins = k ,edgecolor='black',color= UploadColor)

plt.title('Histograma upload')
plt.xlabel('log(bps) upload')
plt.ylabel('Frequência')

plt.show()

#######################################################

#calculando a bin
n = len(chrome_up_max.downLog)
k = round(1 + math.log2(n))

chrome_up_max.downLog.hist(bins = k ,edgecolor='black',color= DownloadColor)

plt.title('Histograma Download')
plt.xlabel('log(bps) download')
plt.ylabel('Frequência')

plt.show()

# %% [markdown]
# ## QQ plot

# %%
plt.figure()
sm.qqplot_2samples(chrome_up_max.upLog,smart_up_max.upLog,line = '45')
plt.title('Q-Q Plot para taxas de download')
plt.show()

# %%
plt.figure()
sm.qqplot_2samples(chrome_down_max.downLog,smart_down_max.downLog,line = '45')
plt.title('Q-Q Plot para taxas de upload')
plt.show()

# %% [markdown]
# # Analise da correlação entre as taxas de upload e download para os horarios com o maior valor de trafego

# %%
coefTaxAmostSmart = smart_up_max['upLog'].corr(smart_down_max['downLog'])
coefTaxAmostChrome = chrome_up_max['upLog'].corr(chrome_down_max['downLog'])

coefTaxAmostSmart, coefTaxAmostChrome
# Out:
# (0.915476744739879, nan)

# %%
plt.figure(figsize=(12, 6))
plt.scatter(smart_up_max['upLog'], smart_down_max['downLog'], color = 'DarkBlue')
plt.title('Scatter UpLog x DownLog da Smart-Tv')
plt.xlabel('log Upload')
plt.ylabel('log Download')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.scatter(chrome_up_max['upLog'], chrome_down_max['downLog'], color = 'DarkBlue')
plt.title('Scatter UpLog x DownLog da Smart-Tv')
plt.xlabel('log Upload')
plt.ylabel('log Download')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 2
#       1 plt.figure(figsize=(12, 6))
# ----> 2 plt.scatter(chrome_up_max['upLog'], chrome_down_max['downLog'], color = 'DarkBlue')
#       3 plt.title('Scatter UpLog x DownLog da Smart-Tv')
#       4 plt.xlabel('log Upload')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# ...
